# %% [markdown]
# # Step 1 — Extract
# Load data from all 3 distinct sources:
# - Source 1: Olist CSV files (Kaggle)
# - Source 2: São Paulo Weather (Open-Meteo REST API)
# - Source 3: Convert Olist Orders to Parquet

# %%
import pandas as pd
import requests
import os

RAW = '../data/raw'
PARQUET = '../data/parquet'
os.makedirs(RAW, exist_ok=True)
os.makedirs(PARQUET, exist_ok=True)
print('Folders ready!')
# Out:
# Folders ready!

# %% [markdown]
# ## Source 1 — Load Olist CSV Files

# %%
# Load all Olist CSV files
orders      = pd.read_csv(f'{RAW}/olist_orders_dataset.csv')
customers   = pd.read_csv(f'{RAW}/olist_customers_dataset.csv')
products    = pd.read_csv(f'{RAW}/olist_products_dataset.csv')
order_items = pd.read_csv(f'{RAW}/olist_order_items_dataset.csv')
payments    = pd.read_csv(f'{RAW}/olist_order_payments_dataset.csv')
reviews     = pd.read_csv(f'{RAW}/olist_order_reviews_dataset.csv')
sellers     = pd.read_csv(f'{RAW}/olist_sellers_dataset.csv')
geolocation = pd.read_csv(f'{RAW}/olist_geolocation_dataset.csv')
category    = pd.read_csv(f'{RAW}/product_category_name_translation.csv')

print('orders:     ', orders.shape)
print('customers:  ', customers.shape)
print('products:   ', products.shape)
print('order_items:', order_items.shape)
print('payments:   ', payments.shape)
print('reviews:    ', reviews.shape)
print('sellers:    ', sellers.shape)
print('All Olist CSV files loaded successfully!')
# Out:
# orders:      (99441, 8)
# customers:   (99441, 5)
# products:    (32951, 9)
# order_items: (112650, 7)
# payments:    (103886, 5)
# reviews:     (99224, 7)
# sellers:     (3095, 4)
# All Olist CSV files loaded successfully!

# %%
# Preview orders
orders.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %% [markdown]
# ## Source 2 — Weather API (Open-Meteo)

# %%
# Fetch São Paulo weather data from Open-Meteo API
url = 'https://archive-api.open-meteo.com/v1/archive'
params = {
    'latitude': -23.5505,
    'longitude': -46.6333,
    'start_date': '2017-01-01',
    'end_date': '2018-08-31',
    'daily': 'temperature_2m_max,precipitation_sum',
    'timezone': 'America/Sao_Paulo'
}

response = requests.get(url, params=params)
print('API Status:', response.status_code)

data = response.json()
weather = pd.DataFrame({
    'date':          data['daily']['time'],
    'temp_max':      data['daily']['temperature_2m_max'],
    'precipitation': data['daily']['precipitation_sum']
})

weather['date'] = pd.to_datetime(weather['date'])
weather.to_csv(f'{RAW}/sao_paulo_weather.csv', index=False)
print(f'Weather data saved: {len(weather)} rows')
weather.head()
# Out:
# API Status: 200
# Weather data saved: 608 rows
#         date  temp_max  precipitation
# 0 2017-01-01      30.1            2.0
# 1 2017-01-02      29.5            5.1
# 2 2017-01-03      28.4            5.0
# 3 2017-01-04      28.8            7.3
# 4 2017-01-05      29.8            3.0

# %% [markdown]
# ## Source 3 — Convert Orders CSV to Parquet

# %%
# Convert Olist orders CSV to Parquet format
orders['order_purchase_timestamp'] = pd.to_datetime(orders['order_purchase_timestamp'])
orders['order_delivered_customer_date'] = pd.to_datetime(orders['order_delivered_customer_date'])
orders['order_estimated_delivery_date'] = pd.to_datetime(orders['order_estimated_delivery_date'])

orders.to_parquet(f'{PARQUET}/olist_orders.parquet', index=False)
print(f'Parquet file saved: {PARQUET}/olist_orders.parquet')
print(f'Shape: {orders.shape}')

# Verify it works
verify = pd.read_parquet(f'{PARQUET}/olist_orders.parquet')
print(f'Verified parquet read back: {verify.shape}')
verify.head()
# Out:
# Parquet file saved: ../data/parquet/olist_orders.parquet
# Shape: (99441, 8)
# Verified parquet read back: (99441, 8)
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
# ...

# %% [markdown]
# ## Summary — All 3 Sources Extracted

# %%
print('=' * 50)
print('EXTRACTION COMPLETE')
print('=' * 50)
print(f'Source 1 - Olist CSVs   : {orders.shape[0]:,} orders loaded')
print(f'Source 2 - Weather API  : {len(weather):,} days of weather')
print(f'Source 3 - Parquet file : olist_orders.parquet created')
print('Ready for Step 2 — Transform!')
# Out:
# ...
# EXTRACTION COMPLETE
# ...
# Source 1 - Olist CSVs   : 99,441 orders loaded
# Source 2 - Weather API  : 608 days of weather
# Source 3 - Parquet file : olist_orders.parquet created
# Ready for Step 2 — Transform!
